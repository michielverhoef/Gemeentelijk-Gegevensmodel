# %% [markdown]
# # Naamswijzgingen importeren en doorvoeren
#
# Dit notebook wordt gebruikt om wijzigingen in naamgeving door te voeren voor
# 1. objecttypes
# 2. attributen
#
# ## Werking Import
#
# De importmodule maakt gebruik van het feit dat het GGM is vastgelegd in Enterprise Architect van Sparx en dat deze de repository van het GGM in [Sqllite](https://www.sqlite.org/index.html) wordt bijgehouden. Deze importmodule leest de te wijzigen namen en past ze aan in de repository.
#
# ## Bedrijfsregels Import
#
# Bij het importeren van vanuit Excels met wijzigingen vindt plaats conform
#
# 1. Matching vindt plaats op basis van ggm-guid;
# 2. de naam wordt overschreven met de nieuw naam

# %%
### Importeer bibliotheken en utils

import os
import pandas as pd
import numpy as np
import json
from IPython.display import JSON as JSONDisplay
import requests
import database
import util
from re import sub
import ast
import re
from treelib import Node, Tree
from datetime import datetime
import math 

import sqlalchemy as sa
from sqlalchemy.orm import sessionmaker
from sqlalchemy import create_engine, inspect
from sqlalchemy.engine import reflection
from sqlalchemy.dialects.postgresql import insert
from sqlalchemy import create_engine, select, MetaData, Table, and_, update, Sequence
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import declarative_base, Session
import uuid



def updateSequence(session, sequence):
    t_seq = session.query(Sequence).filter_by(name=sequence).first()
    newval = int(t_seq.seq) + 1
    
    stmt = update(Sequence).where(Sequence.c.name == sequence).values(seq=newval)
    session.execute(stmt)
    return newval


def generateEAUUID():
    return '{' +  str(uuid.uuid4()).upper() + '}'

def isEmpty(val):
    if not val:
        return True
    elif pd.isna(val):
        return True
    else:
        return False

def setAtrrIfNotEmpty(obj, prop, val):
    if not isEmpty(val):
        setattr(obj, prop, val)

# %% [markdown]
# ## Configuratie
#
# Met de waarden hieronder configureer je de export. Met root_guid geef je de root in de repository weer waar naartoe (en alles eronder) geïmporteerd wordt. Op deze manier kun je ook naar deelmodellen importeren, en alles negeren dat niet bij dat deelmodel hoort. Als voorbeeld zijn naast de root van het hele GGM ook Onderwijs en monumenten getoond.

# %%
### Configuratie
db_uri = "sqlite:///root/Gemeentelijk Gegevensmodel EA16.qea"

now = datetime.now()
dt_string = now.strftime("%d%m%Y-%H:%M:%S")
import_objects = f"./input/ggm_objecttypen_gewijzigd.xlsx"
import_attributes = f"./input/ggm_attributen_gewijzigd.xlsx"

prop_original = 'originele-naam'

# %% [markdown]
# ## Inlezen Wijzigingen Objecttypes
#
# Hieronder worden alle wijzgingen ingelezen.

# %%
# Alle packages inlezen en omzetten in tree structure

df_objects_change = pd.read_excel(import_objects)
df_objects_change.head()
# Out:
#                                           id  alias   archimate_type  \
# 0  EAID_3BF6985C_06AB_4cfc_9A0E_5CC37C224245    NaN      Data object
# 1  EAID_5805FA72_C0CE_43c1_A53F_B81166AEFDD4    NaN  Business object
# 2  EAID_669000E9_25D6_4346_B718_516CDB8B88B7    NaN  Business object
# 3  EAID_8F05E7BA_E7ED_45d1_9626_C8D7FBDB2F1B    NaN  Business object
# 4  EAID_EB35F5B8_9289_49cc_8DF4_8BD20EC662A9    NaN  Business object
#
#      author                                               bron  \
# 0  abrienen                                                NaN
# 1  abrienen                                                NaN
# 2  abrienen                                                NaN
# 3  abrienen                                                NaN
# 4  abrienen  https://www.cbs.nl/nl-nl/onze-diensten/methode...
#
#                created  datum_tijd_export  \
# 0  2019-12-18 13:52:42  28062023-11:06:06
# 1  2019-12-18 14:20:03  28062023-11:06:06
# 2  2019-12-18 14:09:16  28062023-11:06:06
# 3  2019-12-18 14:19:47  28062023-11:06:06
# 4  2019-12-18 14:08:27  28062023-11:06:06
#
#                                                descr  domein_dcat  \
# 0           Persoon waarmee communicatie plaatsvindt          NaN
# 1        Gebouw waar je tegen betaling kunt logeren.          NaN
# 2                              Verblijf in een hotel          NaN
# 3                   Locatie waar iets wordt verkocht          NaN
# 4  De vraag naar arbeid, te berekenen door de tot...          NaN
#
#    domein_gemma  ...             name  \
# 0           NaN  ...          Contact
# 1           NaN  ...            Hotel
# 2           NaN  ...      Hotelbezoek
# 3           NaN  ...      Verkooppunt
# 4           NaN  ...  Werkgelegenheid
#
#                                   package_id phase    status stereotype  \
# 0  EAPK_DB8BA49F_252E_4044_A93B_8215B6903827   1.0  Proposed        NaN
# 1  EAPK_DB8BA49F_252E_4044_A93B_8215B6903827   1.0  Proposed        NaN
# 2  EAPK_DB8BA49F_252E_4044_A93B_8215B6903827   1.0  Proposed        NaN
# 3  EAPK_DB8BA49F_252E_4044_A93B_8215B6903827   1.0  Proposed        NaN
# 4  EAPK_DB8BA49F_252E_4044_A93B_8215B6903827   1.0  Proposed        NaN
#
#    synoniemen toelichting  uri version visibility
# 0         NaN         NaN  NaN     1.0        NaN
# 1         NaN         NaN  NaN     1.0        NaN
# 2         NaN         NaN  NaN     1.0        NaN
# 3         NaN         NaN  NaN     1.0        NaN
# 4         NaN         NaN  NaN     1.0        NaN
#
# [5 rows x 23 columns]

# %%
# engine, suppose it has two tables 'user' and 'address' set up
engine = create_engine(db_uri)
metadata = MetaData(bind=None)

# mapped classes are now created with names by default
# matching that of the table name.
# reflect the tables
Base = automap_base()
Base.prepare(engine, reflect=True)
Object = Base.classes.t_object
Objectproperty = Base.classes.t_objectproperties
Sequence = Table(
    'sqlite_sequence', 
    metadata, 
    autoload=True, 
    autoload_with=engine
)


# Do transformation
session = Session(engine)
var = None
try:
    for index, row in df_objects_change.iterrows():
        ea_guid = '{'+row['id'].replace("EAID_", "").replace("_", "-")+'}'
        t_obj = session.query(Object).filter_by(ea_guid=ea_guid).first()
        if t_obj and t_obj.Object_Type in ['Class','Enumeration'] and t_obj.Name != row['name']:

            # Oude naam wordt als property bewaard
            t_objprop = session.query(Objectproperty).filter_by(Object_ID=t_obj.Object_ID, Property=prop_original).first()
            if not t_objprop:
                #print(f'Property: {prop}')
                seq = updateSequence(session, "t_objectproperties")
                session.add(Objectproperty(PropertyID=seq, Object_ID=t_obj.Object_ID, Property=prop_original, Value=str(t_obj.Name) if not isEmpty(t_obj.Name) else '', ea_guid=generateEAUUID()))
            else:
                t_objprop.Value = t_obj.Name

            
            # Set Object value
            #print(f"Setting Oud: {t_obj.Name} to Nieuw: {row['name']}") 
            t_obj.Name = row['name']
        
        #print(t_obj.Name)
except Exception as e:
    print(f'Foutmelding {ex}')
    raise
        
finally:
    session.commit()
    engine.dispose()

# %% [markdown]
# ## Inlezen Wijzigingen Attributen
#
# Hieronder worden alle wijzgingen ingelezen.

# %%
# Alle packages inlezen en omzetten in tree structure

df_attrs_change = pd.read_excel(import_attributes)
df_attrs_change.head()
# Out:
# /opt/conda/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#                                            id  \
# 0   EAID_B4F60A84_AFBB_4554_9887_DF1020E99DB8
# 1   EAID_DC8B5E9A_144A_4c78_ACAB_908E8DC2C757
# 2   EAID_B8A47DC2_CE92_4e1b_949B_BC2212AC341C
# 3  EAID_dst36212C_BD57_42b6_B51D_E49EA2853F66
# 4  EAID_dst4AC804_79E6_40a6_992F_C50B4F045C90
#
#                                     clazz_id  descr  enumeration_id  \
# 0  EAID_3BF6985C_06AB_4cfc_9A0E_5CC37C224245    NaN             NaN
# 1  EAID_3BF6985C_06AB_4cfc_9A0E_5CC37C224245    NaN             NaN
# 2  EAID_3BF6985C_06AB_4cfc_9A0E_5CC37C224245    NaN             NaN
# 3  EAID_3BF6985C_06AB_4cfc_9A0E_5CC37C224245    NaN             NaN
# 4  EAID_3BF6985C_06AB_4cfc_9A0E_5CC37C224245    NaN             NaN
#
#        name_oud          name  primitive  type_class_id
# 0  contactsoort  contactsoort        NaN            NaN
# 1         datum         datum        NaN            NaN
# 2         tekst         tekst        NaN            NaN
# 3           NaN           NaN        NaN            NaN
# 4           NaN           NaN        NaN            NaN

# %%
# engine, suppose it has two tables 'user' and 'address' set up
engine = create_engine(db_uri)
metadata = MetaData(bind=None)

# mapped classes are now created with names by default
# matching that of the table name.
# reflect the tables
# reflect the tables
Base = automap_base()
Base.prepare(autoload_with=engine, reflect=True) #Base.prepare(engine, reflect=True)
Attribute = Base.classes.t_attribute
Object = Base.classes.t_object
XRef = Base.classes.t_xref
AttributeTag = Base.classes.t_attributetag

Sequence = Table(
    'sqlite_sequence', 
    metadata, 
    autoload=True, 
    autoload_with=engine
)


# Do transformation
session = Session(engine)

for index, row in df_attrs_change.iterrows():
    ea_guid = '{'+row['id'].replace("EAID_", "").replace("_", "-")+'}'
    t_attr = session.query(Attribute).filter_by(ea_guid=ea_guid).first()
    if t_attr and t_attr.Name != row['name']:
        
        t_attrprop = session.query(AttributeTag).filter_by(ElementID=t_attr.ID, Property=prop_original).first()
        if not t_attrprop:
            seq = updateSequence(session, "t_attributetag")
            session.add(AttributeTag(PropertyID=seq, ElementID=t_attr.ID, Property=prop_original, VALUE=str(t_attr.Name), ea_guid=generateEAUUID()))
        else:
            t_attrprop.Value = t_attr.Name

        # Set Object value
        print(f"Setting Oud: {t_attr.Name} to Nieuw: {row['name']}") 
        t_attr.Name = row['name']

    #print(t_obj.Name)
    
session.commit()
engine.dispose()
# Out:
# Setting Oud: aantal kamers to Nieuw: aantalKamers
# Setting Oud: einddatum to Nieuw: datumEind
# Setting Oud: startdatum to Nieuw: datumStart
# Setting Oud: aantalFulletimeVrouwen to Nieuw: aantalFulltimeVrouwen
# Setting Oud: aantalkassa to Nieuw: aantalKassa
# Setting Oud: BronWVO to Nieuw: bronWVO
# Setting Oud: Wvoklasse to Nieuw: wvoKlasse
# Setting Oud: eindeaanwezigheid to Nieuw: eindeAanwezigheid
# Setting Oud: aanstellingsdatum to Nieuw: datumAanstelling
# Setting Oud: uittredingsdatum to Nieuw: datumUittreding
# Setting Oud: aanstellingsdatum to Nieuw: datumAanstelling
# Setting Oud: uittredingsdatum to Nieuw: datumUittreding
# Setting Oud: expiratiedatum to Nieuw: datumExpiratie
# Setting Oud: publicatiedatum to Nieuw: datumPublicatie
# Setting Oud: registratiedatum to Nieuw: datumRegistratie
# Setting Oud: typeraadsstuk to Nieuw: typeRaadsstuk
# Setting Oud: aanvraagdatum to Nieuw: datumAanvraag
# Setting Oud: buitenlandse schoollocatie to Nieuw: buitenlandseSchoollocatie
# Setting Oud: datum retour to Nieuw: datumRetour
# Setting Oud: mutatiedatum to Nieuw: datumMutatie
# Setting Oud: datum afgehandeld to Nieuw: datumAfgehandeld
# Setting Oud: datum ingelicht to Nieuw: datumIngelicht
# Setting Oud: datum uitspraak to Nieuw: datumUitspraak
# Setting Oud: datum zitting to Nieuw: datumZitting
# Setting Oud: einddatum proeftijd to Nieuw: datumEindeProeftijd
# Setting Oud: geldboete voorwaardelijk to Nieuw: geldboeteVoorwaardelijk
# Setting Oud: datum tot to Nieuw: datumTot
# Setting Oud: datum vanaf to Nieuw: datumStart
# Setting Oud: soort verlof to Nieuw: soortVerlof
# Setting Oud: einddatum to Nieuw: datumEind
# Setting Oud: startdatum to Nieuw: datumStart
# Setting Oud: voorstel school to Nieuw: voorstelSchool
# Setting Oud: aanvraagtoegekend to Nieuw: aanvraagToegekend
# Setting Oud: buitenlandseschoollocatie to Nieuw: buitenlandseSchoollocatie
# Setting Oud: einddatum to Nieuw: datumEind
# Setting Oud: startdatum to Nieuw: datumStart
# Setting Oud: eindjaar to Nieuw: jaarEind
# Setting Oud: startjaar to Nieuw: jaarStart
# Setting Oud: kwetsbare jongere to Nieuw: kwetsbareJongere
# Setting Oud: datumbehaald to Nieuw: datumBehaald
# Setting Oud: diplomabehaald to Nieuw: diplomaBehaald
# Setting Oud: einddatum to Nieuw: datumEind
# Setting Oud: startdatum to Nieuw: datumStart
# Setting Oud: vullinggewicht to Nieuw: vullingGewicht
# Setting Oud: Aansluitpunt to Nieuw: aansluitpunt
# Setting Oud: Risicogebied to Nieuw: risicogebied
# Setting Oud: Type to Nieuw: type
# Setting Oud: Type to Nieuw: type
# Setting Oud: TypePlus to Nieuw: typePlus
# Setting Oud: Breedte to Nieuw: breedte
# Setting Oud: Diameter to Nieuw: diameter
# Setting Oud: GewichtLeeg to Nieuw: gewichtLeeg
# Setting Oud: GewichtVol to Nieuw: gewichtVol
# Setting Oud: Hoogte to Nieuw: hoogte
# Setting Oud: Inhoud to Nieuw: inhoud
# Setting Oud: JaarUitgevoerdOnderhoud to Nieuw: jaarOnderhoudUitgevoerd
# Setting Oud: KwaliteitsniveauActueel to Nieuw: kwaliteitsniveauActueel
# Setting Oud: KwaliteitsniveauGewenst to Nieuw: kwaliteitsniveauGewenst
# Setting Oud: Lengte to Nieuw: lengte
# Setting Oud: Materiaal to Nieuw: materiaal
# Setting Oud: Verplaatsbaar to Nieuw: verplaatsbaar
# Setting Oud: Vorm to Nieuw: vorm
# Setting Oud: Type to Nieuw: type
# Setting Oud: TypePlus to Nieuw: typePlus
# Setting Oud: AangemaaktDoor to Nieuw: aangemaaktDoor
# Setting Oud: BeginGarantieperiode to Nieuw: beginGarantieperiode
# Setting Oud: Beheergebied to Nieuw: beheergebied
# Setting Oud: BeheerobjectBeheervak to Nieuw: beheerobjectBeheervak
# Setting Oud: BeheerobjectGebruiksfunctie to Nieuw: beheerobjectGebruiksfunctie
# Setting Oud: BeheerobjectMemo to Nieuw: beheerobjectMemo
# Setting Oud: BeschermdeFloraEnFauna to Nieuw: beschermdeFloraEnFauna
# Setting Oud: Buurt to Nieuw: buurt
# Setting Oud: ConversieID to Nieuw: conversieID
# Setting Oud: EindeGarantieperiode to Nieuw: eindeGarantieperiode
# Setting Oud: Gebiedstype to Nieuw: gebiedstype
# Setting Oud: Gemeente to Nieuw: gemeente
# Setting Oud: Geometrie to Nieuw: geometrie
# Setting Oud: GewijzigdDoor to Nieuw: gewijzigdDoor
# Setting Oud: Grondsoort to Nieuw: grondsoort
# Setting Oud: GrondsoortPlus to Nieuw: grondsoortPlus
# Setting Oud: IMBOR-identificatie to Nieuw: identificatieIMBOR
# Setting Oud: IMGeo-identificatie to Nieuw: identificatieIMGeo
# Setting Oud: JaarVanAanleg to Nieuw: jaarVanAanleg
# Setting Oud: LV-publicatiedatum to Nieuw: datumPublicatieLV
# Setting Oud: Mutatiedatum to Nieuw: datumMutatie
# Setting Oud: Onderhoudsplichtige to Nieuw: onderhoudsplichtige
# Setting Oud: OpenbareRuimte to Nieuw: openbareRuimte
# Setting Oud: Opleverdatum to Nieuw: datumOplevering
# Setting Oud: Postcode to Nieuw: postcode
# Setting Oud: Stadsdeel to Nieuw: stadsdeel
# Setting Oud: Status to Nieuw: status
# Setting Oud: TheoretischEindjaar to Nieuw: theoretischEindjaar
# Setting Oud: TijdstipRegistratie to Nieuw: tijdstipRegistratie
# Setting Oud: TypeBeheerder to Nieuw: typeBeheerder
# Setting Oud: TypeBeheerderPlus to Nieuw: typeBeheerderPlus
# Setting Oud: TypeEigenaar to Nieuw: typeEigenaar
# Setting Oud: TypeEigenaarPlus to Nieuw: typeEigenaarPlus
# Setting Oud: TypeLigging to Nieuw: typeLigging
# Setting Oud: Verwijderdatum to Nieuw: datumVerwijdering
# Setting Oud: Waterschap to Nieuw: waterschap
# Setting Oud: Wijk to Nieuw: wijk
# Setting Oud: Woonplaats to Nieuw: woonplaats
# Setting Oud: Zettingsgevoeligheid to Nieuw: zettingsgevoeligheid
# Setting Oud: ZettingsgevoeligheidPlus to Nieuw: zettingsgevoeligheidPlus
# Setting Oud: Rioleringsgebied to Nieuw: rioleringsgebied
# Setting Oud: BergendVermogen to Nieuw: bergendVermogen
# Setting Oud: PompLedigingsvoorziening to Nieuw: pompLedigingsVoorziening
# Setting Oud: PompSpoelvoorziening to Nieuw: pompSpoelVoorziening
# Setting Oud: Spoelleiding to Nieuw: spoelleiding
# Setting Oud: Vorm to Nieuw: vorm
# Setting Oud: Beleidsstatus to Nieuw: beleidsstatus
# Setting Oud: BeoogdeOmlooptijd to Nieuw: beoogdeOmlooptijd
# Setting Oud: Boombeeld to Nieuw: boombeeld
# Setting Oud: Boombeschermer to Nieuw: boombeschermer
# Setting Oud: Boomgroep to Nieuw: boomgroep
# Setting Oud: BoomhoogteActueel to Nieuw: boomhoogteActueel
# Setting Oud: BoomhoogteklasseActueel to Nieuw: boomhoogteklasseActueel
# Setting Oud: BoomhoogteklasseEindbeeld to Nieuw: boomhoogteklasseEindbeeld
# Setting Oud: Boomspiegel to Nieuw: boomspiegel
# Setting Oud: BoomTypeBeschermingsstatusPlus to Nieuw: boomTypeBeschermingsstatusPlus
# Setting Oud: Boomveiligheidsklasse to Nieuw: veiligheidsklasseBoom
# Setting Oud: Boomvoorziening to Nieuw: boomvoorziening
# Setting Oud: Controlefrequentie to Nieuw: controlefrequentie
# Setting Oud: Feestverlichting to Nieuw: feestverlichting
# Setting Oud: Groeifase to Nieuw: groeifase
# Setting Oud: Groeiplaatsinrichting to Nieuw: groeiplaatsinrichting
# Setting Oud: Herplantplicht to Nieuw: herplantplicht
# Setting Oud: Kiemjaar to Nieuw: kiemjaar
# Setting Oud: KroondiameterklasseActueel to Nieuw: kroondiameterklasseActueel
# Setting Oud: KroondiameterklasseEindbeeld to Nieuw: kroondiameterklasseEindbeeld
# Setting Oud: Kroonvolume to Nieuw: kroonvolume
# Setting Oud: Leeftijd to Nieuw: leeftijd
# Setting Oud: Meerstammig to Nieuw: meerstammig
# Setting Oud: MonetaireBoomwaarde to Nieuw: monetaireBoomwaarde
# Setting Oud: Snoeifase to Nieuw: snoeifase
# Setting Oud: Stamdiameter to Nieuw: stamdiameter
# Setting Oud: Stamdiameterklasse to Nieuw: stamdiameterklasse
# Setting Oud: TakvrijeRuimteTotGebouw to Nieuw: takvrijeRuimteTotGebouw
# Setting Oud: TakvrijeStam to Nieuw: takvrijeStam
# Setting Oud: TakvrijeZonePrimair to Nieuw: takvrijeZonePrimair
# Setting Oud: TakvrijeZoneSecundair to Nieuw: takvrijeZoneSecundair
# Setting Oud: Transponder to Nieuw: transponder
# Setting Oud: Type to Nieuw: type
# Setting Oud: TypeBeschermingsstatus to Nieuw: typeBeschermingsstatus
# Setting Oud: TypeOmgevingsrisicoklasse to Nieuw: typeOmgevingsrisicoklasse
# Setting Oud: TypePlus to Nieuw: typePlus
# Setting Oud: TypeVermeerderingsvorm to Nieuw: typeVermeerderingsvorm
# Setting Oud: Verplant to Nieuw: verplant
# Setting Oud: Verplantbaar to Nieuw: verplantbaar
# Setting Oud: VrijeDoorrijhoogte to Nieuw: vrijeDoorrijhoogte
# Setting Oud: VrijeDoorrijhoogtePrimair to Nieuw: vrijeDoorrijhoogtePrimair
# Setting Oud: VrijeDoorrijhoogteSecundair to Nieuw: vrijeDoorrijhoogteSecundair
# Setting Oud: VrijeTakval to Nieuw: vrijeTakval
# Setting Oud: Breedte to Nieuw: breedte
# Setting Oud: Diameter to Nieuw: diameter
# Setting Oud: Drager to Nieuw: drager
# Setting Oud: Hoogte to Nieuw: hoogte
# Setting Oud: JaarUitgevoerdOnderhoud to Nieuw: jaarOnderhoudUitgevoerd
# Setting Oud: Lengte to Nieuw: lengte
# Setting Oud: Leverancier to Nieuw: leverancier
# Setting Oud: Materiaal to Nieuw: materiaal
# Setting Oud: Vorm to Nieuw: vorm
# Setting Oud: Aanleghoogte to Nieuw: aanleghoogte
# Setting Oud: BouwwerkMateriaal to Nieuw: bouwwerkMateriaal
# Setting Oud: Breedte to Nieuw: breedte
# Setting Oud: Fabrikant to Nieuw: fabrikant
# Setting Oud: Hoogte to Nieuw: hoogte
# Setting Oud: JaarUitgevoerdOnderhoud to Nieuw: jaarOnderhoudUitgevoerd
# Setting Oud: Lengte to Nieuw: lengte
# Setting Oud: Leverancier to Nieuw: leverancier
# Setting Oud: Oppervlakte to Nieuw: oppervlakte
# Setting Oud: TypeFundering to Nieuw: typeFundering
# Setting Oud: AantalOverspanningen to Nieuw: aantalOverspanningen
# Setting Oud: Bedienaar to Nieuw: bedienaar
# Setting Oud: Bedieningstijden to Nieuw: bedieningstijden
# Setting Oud: BelastingklasseNieuw to Nieuw: belastingklasseNieuw
# Setting Oud: BelastingklasseOud to Nieuw: belastingklasseOud
# Setting Oud: Beweegbaar to Nieuw: beweegbaar
# Setting Oud: Doorrijbreedte to Nieuw: doorrijbreedte
# Setting Oud: Draagvermogen to Nieuw: draagvermogen
# Setting Oud: Hoofdroute to Nieuw: hoofdroute
# Setting Oud: Hoofdvaarroute to Nieuw: hoofdvaarroute
# Setting Oud: MaximaalToelaatbaarVoertuiggewicht to Nieuw: maximaalToelaatbaarVoertuiggewicht
# Setting Oud: MaximaleAsbelasting to Nieuw: maximaleAsbelasting
# Setting Oud: MaximaleOverspanning to Nieuw: maximaleOverspanning
# Setting Oud: StatischMoment to Nieuw: statischMoment
# Setting Oud: Type to Nieuw: type
# Setting Oud: TypePlus to Nieuw: typePlus
# Setting Oud: ZwaarsteVoertuig to Nieuw: zwaarsteVoertuig
# Setting Oud: Risicogebied to Nieuw: risicogebied
# Setting Oud: Type to Nieuw: type
# Setting Oud: AantalOverspanningen to Nieuw: aantalOverspanningen
# Setting Oud: Draagvermogen to Nieuw: draagvermogen
# Setting Oud: MaximaalToelaatbaarVoertuiggewicht to Nieuw: maximaalToelaatbaarVoertuiggewicht
# Setting Oud: MaximaleAsbelasting to Nieuw: maximaleAsbelasting
# Setting Oud: MaximaleOverspanning to Nieuw: maximaleOverspanning
# Setting Oud: OverbruggingsobjectDoorrijopening to Nieuw: overbruggingsobjectDoorrijopening
# Setting Oud: Type to Nieuw: type
# Setting Oud: ZwaarsteVoertuig to Nieuw: zwaarsteVoertuig
# Setting Oud: AantalParkeerplaatsen to Nieuw: aantalParkeerplaatsen
# Setting Oud: Type to Nieuw: type
# Setting Oud: TypePlus to Nieuw: typePlus
# Setting Oud: Drain to Nieuw: drain
# Setting Oud: Risicogebied to Nieuw: risicogebied
# Setting Oud: AantalOverspanningen to Nieuw: aantalOverspanningen
# Setting Oud: BelastingklasseNieuw to Nieuw: belastingklasseNieuw
# Setting Oud: BelastingklasseOud to Nieuw: belastingklasseOud
# Setting Oud: Draagvermogen to Nieuw: draagvermogen
# Setting Oud: MaximaalToelaatbaarVoertuiggewicht to Nieuw: maximaalToelaatbaarVoertuiggewicht
# Setting Oud: MaximaleAsbelasting to Nieuw: maximaleAsbelasting
# Setting Oud: MaximaleOverspanning to Nieuw: maximaleOverspanning
# Setting Oud: OverbruggingsobjectDoorrijopening to Nieuw: overbruggingsobjectDoorrijopening
# Setting Oud: Type to Nieuw: type
# Setting Oud: ZwaarsteVoertuig to Nieuw: zwaarsteVoertuig
# Setting Oud: FunctioneelGebiedCode to Nieuw: functioneelGebiedCode
# Setting Oud: FunctioneelGebiedNaam to Nieuw: functioneelGebiedNaam
# Setting Oud: Omtrek to Nieuw: omtrek
# Setting Oud: Oppervlakte to Nieuw: oppervlakte
# Setting Oud: AantalDeuren to Nieuw: aantalDeuren
# Setting Oud: AantalPanelen to Nieuw: aantalPanelen
# Setting Oud: Type to Nieuw: type
# Setting Oud: AantalBedrijfsaansluitingen to Nieuw: aantalBedrijfsaansluitingen
# Setting Oud: AantalHuisaansluitingen to Nieuw: aantalHuisaansluitingen
# Setting Oud: AantalPompen to Nieuw: aantalPompen
# Setting Oud: Bedienaar to Nieuw: bedienaar
# Setting Oud: EffectieveGemaalcapaciteit to Nieuw: effectieveGemaalcapaciteit
# Setting Oud: Hijsinrichting to Nieuw: hijsinrichting
# Setting Oud: Lanceerinrichting to Nieuw: lanceerinrichting
# Setting Oud: PompenInSamenloop to Nieuw: pompenInSamenloop
# Setting Oud: Type to Nieuw: type
# Setting Oud: Veiligheidsrooster to Nieuw: veiligheidsrooster
# Setting Oud: AantalObstakels to Nieuw: aantalObstakels
# Setting Oud: AantalZijden to Nieuw: aantalZijden
# Setting Oud: Afvoeren to Nieuw: afvoeren
# Setting Oud: Bereikbaarheid to Nieuw: bereikbaarheid
# Setting Oud: BergendVermogen to Nieuw: bergendVermogen
# Setting Oud: Bewerkingspercentage to Nieuw: bewerkingspercentage
# Setting Oud: BGTFysiekVoorkomen to Nieuw: bgtFysiekVoorkomen
# Setting Oud: Bollen to Nieuw: bollen
# Setting Oud: Boomveiligheidsklasse to Nieuw: veiligheidsklasseBoom
# Setting Oud: Breedte to Nieuw: breedte
# Setting Oud: BreedteklasseHaag to Nieuw: breedteklasseHaag
# Setting Oud: BVC to Nieuw: bvc
# Setting Oud: CultuurhistorischWaardevol to Nieuw: cultuurhistorischWaardevol
# Setting Oud: Draagkrachtig to Nieuw: draagkrachtig
# Setting Oud: EcologischBeheer to Nieuw: ecologischBeheer
# Setting Oud: GewenstSluitingspercentage to Nieuw: gewenstSluitingspercentage
# Setting Oud: GroenobjectBereikbaarheidPlus to Nieuw: groenobjectBereikbaarheidPlus
# Setting Oud: GroenobjectConstructielaag to Nieuw: groenobjectConstructielaag
# Setting Oud: GroenobjectRand to Nieuw: groenobjectRand
# Setting Oud: GroenobjectSoortnaam to Nieuw: groenobjectSoortnaam
# Setting Oud: HaagvoetLengte to Nieuw: haagvoetLengte
# Setting Oud: HaagvoetOppervlakte to Nieuw: haagvoetOppervlakte
# Setting Oud: Herplantplicht to Nieuw: herplantplicht
# Setting Oud: Hoogte to Nieuw: hoogte
# Setting Oud: HoogteklasseHaag to Nieuw: hoogteklasseHaag
# Setting Oud: IMGeoFysiekVoorkomen to Nieuw: fysiekVoorkomenIMGeo
# Setting Oud: Knipfrequentie to Nieuw: knipfrequentie
# Setting Oud: Knipoppervlakte to Nieuw: knipoppervlakte
# Setting Oud: KwaliteitsniveauActueel to Nieuw: kwaliteitsniveauActueel
# Setting Oud: KwaliteitsniveauGewenst to Nieuw: kwaliteitsniveauGewenst
# Setting Oud: Lengte to Nieuw: lengte
# Setting Oud: Leverancier to Nieuw: leverancier
# Setting Oud: Maaifrequentie to Nieuw: maaifrequentie
# Setting Oud: MaximaleValhoogte to Nieuw: maximaleValhoogte
# Setting Oud: Objectnummer to Nieuw: objectnummer
# Setting Oud: Obstakels to Nieuw: obstakels
# Setting Oud: Omtrek to Nieuw: omtrek
# Setting Oud: Ondergroei to Nieuw: ondergroei
# Setting Oud: Oppervlakte to Nieuw: oppervlakte
# Setting Oud: OpTalud to Nieuw: opTalud
# Setting Oud: Taludsteilte to Nieuw: taludsteilte
# Setting Oud: Type to Nieuw: type
# Setting Oud: TypeBewerking to Nieuw: typeBewerking
# Setting Oud: TypeOmgevingsrisicoklasse to Nieuw: typeOmgevingsrisicoklasse
# Setting Oud: TypePlus to Nieuw: typePlus
# Setting Oud: TypePlus2 to Nieuw: typePlus2
# Setting Oud: Porositeit to Nieuw: porositeit
# Setting Oud: Risicogebied to Nieuw: risicogebied
# Setting Oud: Breedte to Nieuw: breedte
# Setting Oud: EAN-code to Nieuw: eanCode
# Setting Oud: Fabrikant to Nieuw: fabrikant
# Setting Oud: Hoogte to Nieuw: hoogte
# Setting Oud: Inbelgegevens to Nieuw: inbelgegevens
# Setting Oud: Installateur to Nieuw: installateur
# Setting Oud: JaarUitgevoerdOnderhoud to Nieuw: jaarOnderhoudUitgevoerd
# Setting Oud: Lengte to Nieuw: lengte
# Setting Oud: Leverancier to Nieuw: leverancier
# Setting Oud: TypeCommunicatie to Nieuw: typeCommunicatie
# Setting Oud: BelastingklasseNieuw to Nieuw: belastingklasseNieuw
# Setting Oud: BelastingklasseOud to Nieuw: belastingklasseOud
# Setting Oud: Grijpstenen to Nieuw: grijpstenen
# Setting Oud: HoogteBovenkantKademuur to Nieuw: hoogteBovenkantKademuur
# Setting Oud: MateriaalBovenkantKademuur to Nieuw: materiaalBovenkantKademuur
# Setting Oud: OppervlakteBovenkantKademuur to Nieuw: oppervlakteBovenkantKademuur
# Setting Oud: Reddingslijn to Nieuw: reddingslijn
# Setting Oud: Type to Nieuw: type
# Setting Oud: TypeBovenkantKademuur to Nieuw: typeBovenkantKademuur
# Setting Oud: TypeFundering to Nieuw: typeFundering
# Setting Oud: TypeVerankering to Nieuw: typeVerankering
# Setting Oud: AantalDeuren to Nieuw: aantalDeuren
# Setting Oud: BAG-code to Nieuw: bagCode
# Setting Oud: Breedte to Nieuw: breedte
# Setting Oud: EAN-code to Nieuw: eanCode
# Setting Oud: Fabrikant to Nieuw: fabrikant
# Setting Oud: Hoogte to Nieuw: hoogte
# Setting Oud: Inbelgegevens to Nieuw: inbelgegevens
# Setting Oud: Installateur to Nieuw: installateur
# Setting Oud: JaarUitgevoerdOnderhoud to Nieuw: jaarOnderhoudUitgevoerd
# Setting Oud: Kleur to Nieuw: kleur
# Setting Oud: Lengte to Nieuw: lengte
# Setting Oud: Leverancier to Nieuw: leverancier
# Setting Oud: TelecomAdres to Nieuw: adresTelecom
# Setting Oud: TypeCommunicatie to Nieuw: typeCommunicatie
# Setting Oud: TypeFundering to Nieuw: typeFundering
# Setting Oud: TypeSlot to Nieuw: typeSlot
# Setting Oud: Vermogen to Nieuw: vermogen
# Setting Oud: BelastingklasseNieuw to Nieuw: belastingklasseNieuw
# Setting Oud: BelastingklasseOud to Nieuw: belastingklasseOud
# Setting Oud: Type to Nieuw: type
# Setting Oud: Hoogte to Nieuw: hoogte
# Setting Oud: Knipfrequentie to Nieuw: knipfrequentie
# Setting Oud: Knipoppervlakte to Nieuw: knipoppervlakte
# Setting Oud: Ondersteuningsvorm to Nieuw: ondersteuningsvorm
# Setting Oud: Type to Nieuw: type
# Setting Oud: BereikbaarheidKolk to Nieuw: bereikbaarheidKolk
# Setting Oud: Risicogebied to Nieuw: risicogebied
# Setting Oud: Type to Nieuw: type
# Setting Oud: Aanleghoogte to Nieuw: aanleghoogte
# Setting Oud: Anti-graffitiVoorziening to Nieuw: antiGraffitiVoorziening
# Setting Oud: Bereikbaarheid to Nieuw: bereikbaarheid
# Setting Oud: Breedte to Nieuw: breedte
# Setting Oud: Constructietype to Nieuw: constructietype
# Setting Oud: Gewicht to Nieuw: gewicht
# Setting Oud: Hoogte to Nieuw: hoogte
# Setting Oud: Installateur to Nieuw: installateur
# Setting Oud: JaarConserveren to Nieuw: jaarConserveren
# Setting Oud: JaarRenovatie to Nieuw: jaarRenovatie
# Setting Oud: JaarUitgevoerdOnderhoud to Nieuw: jaarOnderhoudUitgevoerd
# Setting Oud: JaarVervanging to Nieuw: jaarVervanging
# Setting Oud: KilometreringBegin to Nieuw: kilometreringBegin
# Setting Oud: KilometreringEind to Nieuw: kilometreringEind
# Setting Oud: Kleur to Nieuw: kleur
# Setting Oud: KunstwerkBereikbaarheidPlus to Nieuw: kunstwerkBereikbaarheidPlus
# Setting Oud: KunstwerkMateriaal to Nieuw: kunstwerkMateriaal
# Setting Oud: KwaliteitsniveauActueel to Nieuw: kwaliteitsniveauActueel
# Setting Oud: KwaliteitsniveauGewenst to Nieuw: kwaliteitsniveauGewenst
# Setting Oud: Lengte to Nieuw: lengte
# Setting Oud: Leverancier to Nieuw: leverancier
# Setting Oud: Looprichel to Nieuw: looprichel
# Setting Oud: MinimumConditiescore to Nieuw: minimumConditiescore
# Setting Oud: Monument to Nieuw: monument
# Setting Oud: Monumentnummer to Nieuw: monumentnummer
# Setting Oud: Objectnaam to Nieuw: objectnaam
# Setting Oud: Objectnummer to Nieuw: objectnummer
# Setting Oud: Onderhoudsregime to Nieuw: onderhoudsregime
# Setting Oud: Oppervlakte to Nieuw: oppervlakte
# Setting Oud: OriÃ«ntatie to Nieuw: oriëntatie
# Setting Oud: TechnischeLevensduur to Nieuw: technischeLevensduur
# Setting Oud: TypeFundering to Nieuw: typeFundering
# Setting Oud: TypeMonument to Nieuw: typeMonument
# Setting Oud: Vervangingswaarde to Nieuw: vervangingswaarde
# Setting Oud: Wegnummer to Nieuw: wegnummer
# Setting Oud: AfwijkendeDieptelegging to Nieuw: afwijkendeDieptelegging
# Setting Oud: Breedte to Nieuw: breedte
# Setting Oud: Diameter to Nieuw: diameter
# Setting Oud: Diepte to Nieuw: diepte
# Setting Oud: EisVoorzorgsmaatregel to Nieuw: eisVoorzorgsmaatregel
# Setting Oud: GeoNauwkeurigheidXY to Nieuw: geoNauwkeurigheidXY
# Setting Oud: Hoogte to Nieuw: hoogte
# Setting Oud: IMKLThema to Nieuw: themaIMKL
# Setting Oud: JaarUitgevoerdOnderhoud to Nieuw: jaarOnderhoudUitgevoerd
# Setting Oud: Lengte to Nieuw: lengte
# Setting Oud: Leverancier to Nieuw: leverancier
# Setting Oud: Materiaal to Nieuw: materiaal
# Setting Oud: VerhoogdRisico to Nieuw: verhoogdRisico
# Setting Oud: AfwijkendeDieptelegging to Nieuw: afwijkendeDieptelegging
# Setting Oud: Diepte to Nieuw: diepte
# Setting Oud: GeoNauwkeurigheidXY to Nieuw: geoNauwkeurigheidXY
# Setting Oud: IMKLThema to Nieuw: themaIMKL
# Setting Oud: JaarUitgevoerdOnderhoud to Nieuw: jaarOnderhoudUitgevoerd
# Setting Oud: Leverancier to Nieuw: leverancier
# Setting Oud: Aanleghoogte to Nieuw: aanleghoogte
# Setting Oud: Aanschafdatum to Nieuw: datumAanschaf
# Setting Oud: Aanschafprijs to Nieuw: prijsAanschaf
# Setting Oud: Bouwjaar to Nieuw: bouwjaar
# Setting Oud: Breedte to Nieuw: breedte
# Setting Oud: Diameter to Nieuw: diameter
# Setting Oud: Fabrikant to Nieuw: fabrikant
# Setting Oud: Gewicht to Nieuw: gewicht
# Setting Oud: Hoogte to Nieuw: hoogte
# Setting Oud: Installateur to Nieuw: installateur
# Setting Oud: JaarUitgevoerdOnderhoud to Nieuw: jaarOnderhoudUitgevoerd
# Setting Oud: Kleur to Nieuw: kleur
# Setting Oud: KwaliteitsniveauActueel to Nieuw: kwaliteitsniveauActueel
# Setting Oud: KwaliteitsniveauGewenst to Nieuw: kwaliteitsniveauGewenst
# Setting Oud: Lengte to Nieuw: lengte
# Setting Oud: Leverancier to Nieuw: leverancier
# Setting Oud: MeubilairMateriaal to Nieuw: meubilairMateriaal
# Setting Oud: Model to Nieuw: model
# Setting Oud: Ondergrond to Nieuw: ondergrond
# Setting Oud: Oppervlakte to Nieuw: oppervlakte
# Setting Oud: PraktischEindjaar to Nieuw: jaarPraktischEind
# Setting Oud: Serienummer to Nieuw: serienummer
# Setting Oud: Transponder to Nieuw: transponder
# Setting Oud: Transponderlocatie to Nieuw: transponderlocatie
# Setting Oud: TypeFundering to Nieuw: typeFundering
# Setting Oud: Typeplaat to Nieuw: typePlaat
# Setting Oud: Aanleghoogte to Nieuw: aanleghoogte
# Setting Oud: Anti-graffitiVoorziening to Nieuw: antiGraffitiVoorziening
# Setting Oud: Bereikbaarheid to Nieuw: bereikbaarheid
# Setting Oud: Breedte to Nieuw: breedte
# Setting Oud: Hoogte to Nieuw: hoogte
# Setting Oud: Installateur to Nieuw: installateur
# Setting Oud: JaarConserveren to Nieuw: jaarConserveren
# Setting Oud: JaarRenovatie to Nieuw: jaarRenovatie
# Setting Oud: JaarUitgevoerdOnderhoud to Nieuw: jaarOnderhoudUitgevoerd
# Setting Oud: JaarVervanging to Nieuw: jaarVervanging
# Setting Oud: Kleur to Nieuw: kleur
# Setting Oud: KwaliteitsniveauActueel to Nieuw: kwaliteitsniveauActueel
# Setting Oud: KwaliteitsniveauGewenst to Nieuw: kwaliteitsniveauGewenst
# Setting Oud: Lengte to Nieuw: lengte
# Setting Oud: Looprichel to Nieuw: looprichel
# Setting Oud: MinimumConditiescore to Nieuw: minimumConditiescore
# Setting Oud: Onderhoudsregime to Nieuw: onderhoudsregime
# Setting Oud: Oppervlakte to Nieuw: oppervlakte
# Setting Oud: OverbruggingsobjectMateriaal to Nieuw: overbruggingsobjectMateriaal
# Setting Oud: OverbruggingsobjectModaliteit to Nieuw: overbruggingsobjectModaliteit
# Setting Oud: TechnischeLevensduur to Nieuw: technischeLevensduur
# Setting Oud: TypeFundering to Nieuw: typeFundering
# Setting Oud: Vervangingswaarde to Nieuw: vervangingswaarde
# Setting Oud: Bassin to Nieuw: bassin
# Setting Oud: Drempelbreedte to Nieuw: drempelbreedte
# Setting Oud: Drempelniveau to Nieuw: drempelniveau
# Setting Oud: Klep to Nieuw: klep
# Setting Oud: Type to Nieuw: type
# Setting Oud: VormDrempel to Nieuw: vormDrempel
# Setting Oud: Waking to Nieuw: waking
# Setting Oud: Breedte to Nieuw: breedte
# Setting Oud: Diameter to Nieuw: diameter
# Setting Oud: Hoogte to Nieuw: hoogte
# Setting Oud: JaarUitgevoerdOnderhoud to Nieuw: jaarOnderhoudUitgevoerd
# Setting Oud: KwaliteitsniveauActueel to Nieuw: kwaliteitsniveauActueel
# Setting Oud: KwaliteitsniveauGewenst to Nieuw: kwaliteitsniveauGewenst
# Setting Oud: Lengte to Nieuw: lengte
# Setting Oud: Leverancier to Nieuw: leverancier
# Setting Oud: Materiaal to Nieuw: materiaal
# Setting Oud: Vorm to Nieuw: vorm
# Setting Oud: Aanslagniveau to Nieuw: aanslagniveau
# Setting Oud: BeginstandDraaiurenteller to Nieuw: beginstandDraaiurenteller
# Setting Oud: Besturingskast to Nieuw: besturingskast
# Setting Oud: LaatsteStandDraaiurenteller to Nieuw: laatsteStandDraaiurenteller
# Setting Oud: LaatsteStandkWhTeller to Nieuw: laatsteStandkWhTeller
# Setting Oud: Levensduur to Nieuw: levensduur
# Setting Oud: Model to Nieuw: model
# Setting Oud: Motorvermogen to Nieuw: motorvermogen
# Setting Oud: OnderdeelMetPomp to Nieuw: onderdeelMetPomp
# Setting Oud: Ontwerpcapaciteit to Nieuw: ontwerpcapaciteit
# Setting Oud: Pompcapaciteit to Nieuw: pompcapaciteit
# Setting Oud: Serienummer to Nieuw: serienummer
# Setting Oud: Type to Nieuw: type
# Setting Oud: TypeOnderdeelMetPomp to Nieuw: typeOnderdeelMetPomp
# Setting Oud: TypePlus to Nieuw: typePlus
# Setting Oud: TypeWaaier to Nieuw: typeWaaier
# Setting Oud: Uitslagpeil to Nieuw: uitslagpeil
# Setting Oud: BovengrondsZichtbaar to Nieuw: bovengrondsZichtbaar
# Setting Oud: Breedte to Nieuw: breedte
# Setting Oud: Diameter to Nieuw: diameter
# Setting Oud: Hoogte to Nieuw: hoogte
# Setting Oud: JaarUitgevoerdOnderhoud to Nieuw: jaarOnderhoudUitgevoerd
# Setting Oud: Lengte to Nieuw: lengte
# Setting Oud: Leverancier to Nieuw: leverancier
# Setting Oud: Maaiveldhoogte to Nieuw: maaiveldhoogte
# Setting Oud: Materiaal to Nieuw: materiaal
# Setting Oud: Toegankelijk to Nieuw: toegankelijk
# Setting Oud: TypeAfdekking to Nieuw: typeAfdekking
# Setting Oud: Vorm to Nieuw: vorm
# Setting Oud: Wanddikte to Nieuw: wanddikte
# Setting Oud: Diameter to Nieuw: diameter
# Setting Oud: Put to Nieuw: put
# Setting Oud: Type to Nieuw: type
# Setting Oud: Vorm to Nieuw: vorm
# Setting Oud: Rioleringsgebied to Nieuw: rioleringsgebied
# Setting Oud: Zuiveringsgebied to Nieuw: zuiveringsgebied
# Setting Oud: AantalBedrijven to Nieuw: aantalBedrijven
# Setting Oud: AantalRecreatie to Nieuw: aantalRecreatie
# Setting Oud: AantalWoningen to Nieuw: aantalWoningen
# Setting Oud: AfvoerendOppervlak to Nieuw: afvoerendOppervlak
# Setting Oud: BergendOppervlak to Nieuw: bergendOppervlak
# Setting Oud: RioolputConstructieonderdeel to Nieuw: rioolputConstructieonderdeel
# Setting Oud: RioolputRioolleiding to Nieuw: rioolputRioolleiding
# Setting Oud: Risicogebied to Nieuw: risicogebied
# Setting Oud: ToegangBreedte to Nieuw: toegangBreedte
# Setting Oud: ToegangLengte to Nieuw: toegangLengte
# Setting Oud: Type to Nieuw: type
# Setting Oud: TypePlus to Nieuw: typePlus
# Setting Oud: Aanleghoogte to Nieuw: aanleghoogte
# Setting Oud: Breedte to Nieuw: breedte
# Setting Oud: Hoogte to Nieuw: hoogte
# Setting Oud: JaarUitgevoerdOnderhoud to Nieuw: jaarOnderhoudUitgevoerd
# Setting Oud: Lengte to Nieuw: lengte
# Setting Oud: Leverancier to Nieuw: leverancier
# Setting Oud: Objectnaam to Nieuw: objectnaam
# Setting Oud: Objectnummer to Nieuw: objectnummer
# Setting Oud: Oppervlakte to Nieuw: oppervlakte
# Setting Oud: ScheidingMateriaal to Nieuw: scheidingMateriaal
# Setting Oud: Verplaatsbaar to Nieuw: verplaatsbaar
# Setting Oud: Aanleghoogte to Nieuw: aanleghoogte
# Setting Oud: Elektrakast to Nieuw: elektrakast
# Setting Oud: Frequentie-omvormerÂ Â  to Nieuw: frequentieOmvormer
# Setting Oud: Hoogte to Nieuw: hoogte
# Setting Oud: JaarUitgevoerdOnderhoud to Nieuw: jaarOnderhoudUitgevoerd
# Setting Oud: Leverancier to Nieuw: leverancier
# Setting Oud: Meetpunt to Nieuw: meetpunt
# Setting Oud: PLC to Nieuw: plc
# Setting Oud: Hoogte to Nieuw: hoogte
# Setting Oud: Type to Nieuw: type
# Setting Oud: JaarHerinrichting to Nieuw: jaarHerinrichting
# Setting Oud: SpeelterreinLeeftijdDoelgroep to Nieuw: speelterreinLeeftijdDoelgroep
# Setting Oud: Type to Nieuw: type
# Setting Oud: TypePlus to Nieuw: typePlus
# Setting Oud: Catalogusprijs to Nieuw: catalogusprijs
# Setting Oud: Certificaat to Nieuw: certificaat
# Setting Oud: Certificaatdatum to Nieuw: datumCertificaat
# Setting Oud: Certificaatnummer to Nieuw: certificaatnummer
# Setting Oud: Certificeringsinstantie to Nieuw: certificeringsinstantie
# Setting Oud: Controlefrequentie to Nieuw: controlefrequentie
# Setting Oud: GemakkelijkToegankelijk to Nieuw: gemakkelijkToegankelijk
# Setting Oud: Inspectievolgorde to Nieuw: inspectievolgorde
# Setting Oud: Installatiekosten to Nieuw: installatiekosten
# Setting Oud: Speelterrein to Nieuw: speelterrein
# Setting Oud: SpeeltoestelToestelonderdeel to Nieuw: speeltoestelToestelonderdeel
# Setting Oud: TechnischeLevensduur to Nieuw: technischeLevensduur
# Setting Oud: Toestelcode to Nieuw: toestelcode
# Setting Oud: Toestelgroep to Nieuw: toestelgroep
# Setting Oud: Toestelnaam to Nieuw: toestelnaam
# Setting Oud: Type to Nieuw: type
# Setting Oud: Typenummer to Nieuw: typenummer
# Setting Oud: TypePlus to Nieuw: typePlus
# Setting Oud: TypePlus2 to Nieuw: typePlus2
# Setting Oud: ValruimteHoogte to Nieuw: valruimteHoogte
# Setting Oud: ValruimteOmvang to Nieuw: valruimteOmvang
# Setting Oud: VrijeValhoogte to Nieuw: vrijeValhoogte
# Setting Oud: Drainage to Nieuw: drainage
# Setting Oud: Gebruiksvorm to Nieuw: gebruiksvorm
# Setting Oud: Sportcomplex to Nieuw: sportcomplex
# Setting Oud: SportterreinTypeSport to Nieuw: sportterreinTypeSport
# Setting Oud: Type to Nieuw: type
# Setting Oud: TypePlus to Nieuw: typePlus
# Setting Oud: Veldnummer to Nieuw: veldnummer
# Setting Oud: Verlicht to Nieuw: verlicht
# Setting Oud: Bemalingsgebied to Nieuw: bemalingsgebied
# Setting Oud: Breedte to Nieuw: breedte
# Setting Oud: CultuurhistorischWaardevol to Nieuw: cultuurhistorischWaardevol
# Setting Oud: Herplantplicht to Nieuw: herplantplicht
# Setting Oud: Oppervlakte to Nieuw: oppervlakte
# Setting Oud: OpTalud to Nieuw: opTalud
# Setting Oud: PercentageLoofbos to Nieuw: percentageLoofbos
# Setting Oud: TerreindeelSoortnaam to Nieuw: terreindeelSoortnaam
# Setting Oud: Type to Nieuw: type
# Setting Oud: TypeBewerking to Nieuw: typeBewerking
# Setting Oud: TypePlus to Nieuw: typePlus
# Setting Oud: TypePlus2 to Nieuw: typePlus2
# Setting Oud: Aanleghoogte to Nieuw: aanleghoogte
# Setting Oud: AantalTunnelbuizen to Nieuw: aantalTunnelbuizen
# Setting Oud: Breedte to Nieuw: breedte
# Setting Oud: Doorrijbreedte to Nieuw: doorrijbreedte
# Setting Oud: Doorrijhoogte to Nieuw: doorrijhoogte
# Setting Oud: Hoogte to Nieuw: hoogte
# Setting Oud: JaarConserveren to Nieuw: jaarConserveren
# Setting Oud: JaarUitgevoerdOnderhoud to Nieuw: jaarOnderhoudUitgevoerd
# Setting Oud: Lengte to Nieuw: lengte
# Setting Oud: Leverancier to Nieuw: leverancier
# Setting Oud: Objectnaam to Nieuw: objectnaam
# Setting Oud: Objectnummer to Nieuw: objectnummer
# Setting Oud: Oppervlakte to Nieuw: oppervlakte
# Setting Oud: TunnelobjectMateriaal to Nieuw: tunnelobjectMateriaal
# Setting Oud: Type to Nieuw: type
# Setting Oud: Waterobject to Nieuw: waterobject
# Setting Oud: Afvoeren to Nieuw: afvoeren
# Setting Oud: Bereikbaarheid to Nieuw: bereikbaarheid
# Setting Oud: EcologischBeheer to Nieuw: ecologischBeheer
# Setting Oud: KwaliteitsniveauActueel to Nieuw: kwaliteitsniveauActueel
# Setting Oud: KwaliteitsniveauGewenst to Nieuw: kwaliteitsniveauGewenst
# Setting Oud: Kweker to Nieuw: kweker
# Setting Oud: Leverancier to Nieuw: leverancier
# Setting Oud: Objectnummer to Nieuw: objectnummer
# Setting Oud: Soortnaam to Nieuw: soortnaam
# Setting Oud: TypeStandplaats to Nieuw: typeStandplaats
# Setting Oud: TypeStandplaatsPlus to Nieuw: typeStandplaatsPlus
# Setting Oud: VegetatieobjectBereikbaarheidPlus to Nieuw: vegetatieobjectBereikbaarheidPlus
# Setting Oud: Aanleghoogte to Nieuw: aanleghoogte
# Setting Oud: AanOfVrijliggend to Nieuw: aanOfVrijliggend
# Setting Oud: Aanschafprijs to Nieuw: prijsAanschaf
# Setting Oud: AantalDeklagen to Nieuw: aantalDeklagen
# Setting Oud: AantalOnderlagen to Nieuw: aantalOnderlagen
# Setting Oud: AantalTussenlagen to Nieuw: aantalTussenlagen
# Setting Oud: Afmeting to Nieuw: afmeting
# Setting Oud: Belasting to Nieuw: belasting
# Setting Oud: BergendVermogen to Nieuw: bergendVermogen
# Setting Oud: BGTFysiekVoorkomen to Nieuw: bgtFysiekVoorkomen
# Setting Oud: Breedte to Nieuw: breedte
# Setting Oud: DikteConstructie to Nieuw: dikteConstructie
# Setting Oud: Draagkrachtig to Nieuw: draagkrachtig
# Setting Oud: Formaat to Nieuw: formaat
# Setting Oud: Geluidsreducerend to Nieuw: geluidsreducerend
# Setting Oud: IMGeoFysiekVoorkomen to Nieuw: fysiekVoorkomenIMGeo
# Setting Oud: JaarConserveren to Nieuw: jaarConserveren
# Setting Oud: JaarUitgevoerdOnderhoud to Nieuw: jaarOnderhoudUitgevoerd
# Setting Oud: Kleur to Nieuw: kleur
# Setting Oud: KwaliteitsniveauActueel to Nieuw: kwaliteitsniveauActueel
# Setting Oud: KwaliteitsniveauGewenst to Nieuw: kwaliteitsniveauGewenst
# Setting Oud: Lengte to Nieuw: lengte
# Setting Oud: LengteKunstgras to Nieuw: lengteKunstgras
# Setting Oud: LengteVoegen to Nieuw: lengteVoegen
# Setting Oud: Levensduur to Nieuw: levensduur
# Setting Oud: Materiaal to Nieuw: materiaal
# Setting Oud: MaximaleValhoogte to Nieuw: maximaleValhoogte
# Setting Oud: Omtrek to Nieuw: omtrek
# Setting Oud: Ondergrondcode to Nieuw: ondergrondcode
# Setting Oud: Oppervlakte to Nieuw: oppervlakte
# Setting Oud: OpTalud to Nieuw: opTalud
# Setting Oud: PlaatsoriÃ«ntatie to Nieuw: plaatsoriëntatie
# Setting Oud: PraktischEindjaar to Nieuw: jaarPraktischEind
# Setting Oud: Rijstrook to Nieuw: rijstrook
# Setting Oud: SoortVoeg to Nieuw: soortVoeg
# Setting Oud: ToelichtingGemengdeBestrating to Nieuw: toelichtingGemengdeBestrating
# Setting Oud: Type to Nieuw: type
# Setting Oud: TypeConstructie to Nieuw: typeConstructie
# Setting Oud: TypeFundering to Nieuw: typeFundering
# Setting Oud: TypePlus to Nieuw: typePlus
# Setting Oud: TypePlus2 to Nieuw: typePlus2
# Setting Oud: TypeRijstrook to Nieuw: typeRijstrook
# Setting Oud: TypeVoeg to Nieuw: typeVoeg
# Setting Oud: TypeVoegvulling to Nieuw: typeVoegvulling
# Setting Oud: Vegen to Nieuw: vegen
# Setting Oud: VerhardingsobjectConstructielaag to Nieuw: verhardingsobjectConstructielaag
# Setting Oud: VerhardingsobjectModaliteit to Nieuw: verhardingsobjectModaliteit
# Setting Oud: VerhardingsobjectRand to Nieuw: verhardingsobjectRand
# Setting Oud: VerhardingsobjectWegfunctie to Nieuw: verhardingsobjectWegfunctie
# Setting Oud: VerhoogdeLigging to Nieuw: verhoogdeLigging
# Setting Oud: VulmateriaalKunstgras to Nieuw: vulmateriaalKunstgras
# Setting Oud: Waterdoorlatendheid to Nieuw: waterdoorlatendheid
# Setting Oud: Wegas to Nieuw: wegas
# Setting Oud: WegcategorieDV to Nieuw: wegcategorieDV
# Setting Oud: WegcategorieDVPlus to Nieuw: wegcategorieDVPlus
# Setting Oud: Wegnummer to Nieuw: wegnummer
# Setting Oud: WegtypeBestaand to Nieuw: wegtypeBestaand
# Setting Oud: Wegvak to Nieuw: wegvak
# Setting Oud: Wegvaknummer to Nieuw: wegvaknummer
# Setting Oud: Ontwerpsnelheid to Nieuw: ontwerpsnelheid
# Setting Oud: Type to Nieuw: type
# Setting Oud: TypePlus to Nieuw: typePlus
# Setting Oud: AantalOverspanningen to Nieuw: aantalOverspanningen
# Setting Oud: BelastingklasseNieuw to Nieuw: belastingklasseNieuw
# Setting Oud: BelastingklasseOud to Nieuw: belastingklasseOud
# Setting Oud: Draagvermogen to Nieuw: draagvermogen
# Setting Oud: MaximaalToelaatbaarVoertuiggewicht to Nieuw: maximaalToelaatbaarVoertuiggewicht
# Setting Oud: MaximaleAsbelasting to Nieuw: maximaleAsbelasting
# Setting Oud: MaximaleOverspanning to Nieuw: maximaleOverspanning
# Setting Oud: OverbruggingsobjectDoorrijopening to Nieuw: overbruggingsobjectDoorrijopening
# Setting Oud: Type to Nieuw: type
# Setting Oud: Waterobject to Nieuw: waterobject
# Setting Oud: ZwaarsteVoertuig to Nieuw: zwaarsteVoertuig
# Setting Oud: Aanleghoogte to Nieuw: aanleghoogte
# Setting Oud: Breedte to Nieuw: breedte
# Setting Oud: JaarConserveren to Nieuw: jaarConserveren
# Setting Oud: JaarUitgevoerdOnderhoud to Nieuw: jaarOnderhoudUitgevoerd
# Setting Oud: KwaliteitsniveauActueel to Nieuw: kwaliteitsniveauActueel
# Setting Oud: KwaliteitsniveauGewenst to Nieuw: kwaliteitsniveauGewenst
# Setting Oud: Lengte to Nieuw: lengte
# Setting Oud: Leverancier to Nieuw: leverancier
# Setting Oud: Materiaal to Nieuw: materiaal
# Setting Oud: Oppervlakte to Nieuw: oppervlakte
# Setting Oud: Breedte to Nieuw: breedte
# Setting Oud: Folie to Nieuw: folie
# Setting Oud: Hoogte to Nieuw: hoogte
# Setting Oud: InfiltrerendOppervlak to Nieuw: infiltrerendOppervlak
# Setting Oud: InfiltrerendVermogen to Nieuw: infiltrerendVermogen
# Setting Oud: Lengte to Nieuw: lengte
# Setting Oud: Lozingspunt to Nieuw: lozingspunt
# Setting Oud: Oppervlakte to Nieuw: oppervlakte
# Setting Oud: Porositeit to Nieuw: porositeit
# Setting Oud: Streefdiepte to Nieuw: streefdiepte
# Setting Oud: Type to Nieuw: type
# Setting Oud: TypePlus to Nieuw: typePlus
# Setting Oud: TypePlus2 to Nieuw: typePlus2
# Setting Oud: TypeVaarwater to Nieuw: typeVaarwater
# Setting Oud: TypeWaterplant to Nieuw: typeWaterplant
# Setting Oud: Uitstroomniveau to Nieuw: uitstroomniveau
# Setting Oud: Vaarwegtraject to Nieuw: vaarwegtraject
# Setting Oud: Vorm to Nieuw: vorm
# Setting Oud: Waternaam to Nieuw: waternaam
# Setting Oud: Waterpeil to Nieuw: waterpeil
# Setting Oud: WaterpeilWinter to Nieuw: waterpeilWinter
# Setting Oud: WaterpeilZomer to Nieuw: waterpeilZomer
# Setting Oud: Waterplanten to Nieuw: waterplanten
# Setting Oud: Aanleghoogte to Nieuw: aanleghoogte
# Setting Oud: Breedte to Nieuw: breedte
# Setting Oud: Hoogte to Nieuw: hoogte
# Setting Oud: JaarConserveren to Nieuw: jaarConserveren
# Setting Oud: JaarUitgevoerdOnderhoud to Nieuw: jaarOnderhoudUitgevoerd
# Setting Oud: KwaliteitsniveauActueel to Nieuw: kwaliteitsniveauActueel
# Setting Oud: KwaliteitsniveauGewenst to Nieuw: kwaliteitsniveauGewenst
# Setting Oud: Lengte to Nieuw: lengte
# Setting Oud: Leverancier to Nieuw: leverancier
# Setting Oud: Materiaal to Nieuw: materiaal
# Setting Oud: Oppervlakte to Nieuw: oppervlakte
# Setting Oud: WeginrichtingsobjectWegfunctie to Nieuw: weginrichtingsobjectWegfunctie
# Setting Oud: Datum begin geldigheid to Nieuw: datumBeginGeldigheid
# Setting Oud: Datum einde geldigheid to Nieuw: datumEindeGeldigheid
# Setting Oud: Geometriesoort to Nieuw: geometrieSoort
# Setting Oud: Identificatie to Nieuw: identificatie
# Setting Oud: adviesdatum to Nieuw: datumAdvies
# Setting Oud: meldingdatum to Nieuw: datumMelding
# Setting Oud: uitvoeringsdatum to Nieuw: datumUitvoering
# Setting Oud: Aanmelddatum to Nieuw: datumAanmelding
# Setting Oud: datumgoedkeuring to Nieuw: datumGoedkeuring
# Setting Oud: herstelwerkzaamheden vereist to Nieuw: herstelwerkzaamhedenVereist
# Setting Oud: omschrijving herstelwerkzaamheden to Nieuw: omschrijvingHerstelwerkzaamheden
# Setting Oud: Wegbeheerder to Nieuw: wegbeheerder
# Setting Oud: 70% verkocht to Nieuw: 70ProcentVerkocht
# Setting Oud: bestemming goedgekeurd to Nieuw: bestemmingGoedgekeurd
# Setting Oud: eerste oplevering to Nieuw: eersteOplevering
# Setting Oud: eigendom gemeente to Nieuw: eigendomGemeente
# Setting Oud: laatste oplevering to Nieuw: laatsteOplevering
# Setting Oud: aantal adressen to Nieuw: aantalAdressen
# Setting Oud: aantal kamers to Nieuw: aantalKamers
# Setting Oud: project-id to Nieuw: projectID
# Setting Oud: kadastraal perceel to Nieuw: kadastraalPerceel
# Setting Oud: Kadastrale gemeente to Nieuw: kadastraleGemeente
# Setting Oud: Kadastrale Sectie to Nieuw: kadastraleSectie
# Setting Oud: vraag-id to Nieuw: vraagID
# Setting Oud: vraag classificatie to Nieuw: vraagClassificatie
# Setting Oud: indiendatum to Nieuw: datumIndien
# Setting Oud: referentie aanvrager to Nieuw: referentieAanvrager
# Setting Oud: toelichting later aan te leveren informatie to Nieuw: toelichtingLaterAanTeLeverenInformatie
# Setting Oud: toelichting niet aan te leveren informatie to Nieuw: toelichtingNietAanTeLeverenInformatie
# Setting Oud: toelichting verzoek to Nieuw: toelichtingVerzoek
# Setting Oud: Verzoeknummer to Nieuw: verzoeknummer
# Setting Oud: Volgnummer to Nieuw: volgnummer
# Setting Oud: datum bekend to Nieuw: datumBekend
# Setting Oud: datum in werking to Nieuw: datumInWerking
# Setting Oud: geldig tot to Nieuw: datumEindeGeldigheid
# Setting Oud: geldig vanaf to Nieuw: datumStart
# Setting Oud: kwalitatieve waarde to Nieuw: kwalitatieveWaarde
# Setting Oud: kwantitatieve waarde eenheid to Nieuw: kwantitatieveWaardeEenheid
# Setting Oud: kwantitatieve waarde omvang to Nieuw: kwantitatieveWaardeOmvang
# Setting Oud: omgevingsnorm groep to Nieuw: omgevingsnormGroep
# Setting Oud: omgevingswaarde groep to Nieuw: omgevingswaardeGroep
# Setting Oud: activiteitregelkwalificatie to Nieuw: activiteitRegelKwalificatie
# Setting Oud: begindatum geldigheid to Nieuw: datumBeginGeldigheid
# Setting Oud: einddatum geldigheid to Nieuw: datumEindeGeldigheid
# Setting Oud: soort aansluitpunt to Nieuw: soortAansluitpunt
# Setting Oud: geldig tot to Nieuw: datumEindeGeldigheid
# Setting Oud: geldig vanaf to Nieuw: datumStart
# Setting Oud: artefectnr to Nieuw: artefectnummer
# Setting Oud: dateringcomplex to Nieuw: dateringComplex
# Setting Oud: herkomstXXX to Nieuw: herkomst
# Setting Oud: key_doos to Nieuw: keyDoos
# Setting Oud: key_magazijnplaatsing to Nieuw: keyMagazijnplaatsing
# Setting Oud: key_put to Nieuw: keyPut
# Setting Oud: key_vondst to Nieuw: keyVondst
# Setting Oud: projectcd to Nieuw: projectCD
# Setting Oud: putnr to Nieuw: putnummer
# Setting Oud: vondstnr to Nieuw: vondstnummer
# Setting Oud: doosnr to Nieuw: doosnummer
# Setting Oud: key_magazijnlocatie to Nieuw: keyMagazijnlocatie
# Setting Oud: projectcd to Nieuw: projectCD
# Setting Oud: datumgeplaatst to Nieuw: datumGeplaatst
# Setting Oud: key_doos to Nieuw: keyDoos
# Setting Oud: key_magazijnlocatie to Nieuw: keyMagazijnlocatie
# Setting Oud: projectcd to Nieuw: projectCD
# Setting Oud: einddatum to Nieuw: datumEind
# Setting Oud: jaartot to Nieuw: jaarTot
# Setting Oud: jaarvan to Nieuw: jaarVan
# Setting Oud: projectcd to Nieuw: projectCD
# Setting Oud: startdatum to Nieuw: datumStart
# Setting Oud: projectcd to Nieuw: projectCD
# Setting Oud: putnr to Nieuw: putnummer
# Setting Oud: hoogte boven to Nieuw: hoogteBoven
# Setting Oud: hoogte onder to Nieuw: hoogteOnder
# Setting Oud: key_vlak to Nieuw: keyVlak
# Setting Oud: projectcd to Nieuw: projectCD
# Setting Oud: putnr to Nieuw: putnummer
# Setting Oud: spoornr to Nieuw: spoorNummer
# Setting Oud: vlaknr to Nieuw: vlaknummer
# Setting Oud: dieptetot to Nieuw: diepteTot
# Setting Oud: dieptevan to Nieuw: diepteVan
# Setting Oud: key_put to Nieuw: keyPut
# Setting Oud: projectcd to Nieuw: projectCD
# Setting Oud: putnr to Nieuw: putnummer
# Setting Oud: vlaknr to Nieuw: vlaknummer
# Setting Oud: key_vulling to Nieuw: keyVulling
# Setting Oud: projectcd to Nieuw: projectCD
# Setting Oud: putnr to Nieuw: putnummer
# Setting Oud: spoornr to Nieuw: spoorNummer
# Setting Oud: vlaknr to Nieuw: vlaknummer
# Setting Oud: vondstnr to Nieuw: vondstnummer
# Setting Oud: vullingnr to Nieuw: vullingnummer
# Setting Oud: xcoord to Nieuw: xCoordinaat
# Setting Oud: ycoord to Nieuw: yCoordinaat
# Setting Oud: key_spoor to Nieuw: keySpoor
# Setting Oud: projectcd to Nieuw: projectCD
# Setting Oud: putnr to Nieuw: putnummer
# Setting Oud: spoornr to Nieuw: spoorNummer
# Setting Oud: vlaknr to Nieuw: vlaknummer
# Setting Oud: vullingnr to Nieuw: vullingnummer
# Setting Oud: uiterlijke vorm to Nieuw: uiterlijkeVorm
# Setting Oud: geboortedatum to Nieuw: datumGeboorte
# Setting Oud: overlijdensdatum to Nieuw: datumOverlijden
# Setting Oud: ambachtjaartot to Nieuw: jaarAmbachtTot
# Setting Oud: ambachtjaarvanaf to Nieuw: jaarAmbachtVanaf
# Setting Oud: gemeentelijkmonumentcode to Nieuw: gemeentelijkMonumentCode
# Setting Oud: bouwjaartot to Nieuw: bouwjaarTot
# Setting Oud: bouwjaarvan to Nieuw: bouwjaarVan
# Setting Oud: dateringtot to Nieuw: dateringTot
# Setting Oud: dateringvanaf to Nieuw: dateringVanaf
# Setting Oud: geboortedatum to Nieuw: datumGeboorte
# Setting Oud: publiek toegankelijk to Nieuw: publiekToegankelijk
# Setting Oud: sterfdatum to Nieuw: datumOverlijden
# Setting Oud: aantal personen to Nieuw: aantalPersonen
# Setting Oud: gebruikt op to Nieuw: gebruiktOp
# Setting Oud: geldigtot to Nieuw: datumEindeGeldigheid
# Setting Oud: geldigvanaf to Nieuw: datumStart
# Setting Oud: datumtot to Nieuw: datumTot
# Setting Oud: datumvanaf to Nieuw: datumStart
# Setting Oud: aangavraagddoor to Nieuw: aanvraagDoor
# Setting Oud: aanvraagdatum to Nieuw: datumAanvraag
# Setting Oud: begindatum to Nieuw: datumStart
# Setting Oud: einddatum to Nieuw: datumEind
# Setting Oud: toestemmingdoor to Nieuw: toestemmingDoor
# Setting Oud: Opmerkingen to Nieuw: opmerkingen
# Setting Oud: bezit tot to Nieuw: bezitTot
# Setting Oud: bezit vanaf to Nieuw: bezitVanaf
# Setting Oud: geldig tot to Nieuw: datumEindeGeldigheid
# Setting Oud: geldig vanaf to Nieuw: datumStart
# Setting Oud: code museumjaarkaart to Nieuw: codeMuseumjaarkaart
# Setting Oud: geldig tot to Nieuw: datumEindeGeldigheid
# Setting Oud: geldig vanaf to Nieuw: datumStart
# Setting Oud: BTW to Nieuw: btw
# Setting Oud: prijs ex BTW to Nieuw: prijsExBTW
# Setting Oud: tijdtot to Nieuw: tijdTot
# Setting Oud: tijdvanaf to Nieuw: tijdVanaf
# Setting Oud: naam instelling to Nieuw: naamInstelling
# Setting Oud: einddatum to Nieuw: datumEind
# Setting Oud: startdatum to Nieuw: datumStart
# Setting Oud: aantal beschikbaar to Nieuw: aantalBeschikbaar
# Setting Oud: aantal in bestelling to Nieuw: aantalInBestelling
# Setting Oud: leverdatum bestelling to Nieuw: datumLeveringBestelling
# Setting Oud: geschatte kosten per jaar to Nieuw: geschatteKostenPerJaar
# Setting Oud: klokuren onderwijs to Nieuw: klokurenOnderwijs
# Setting Oud: klokuren verenigingen to Nieuw: klokurenVerenigingen
# Setting Oud: aantalnormteams to Nieuw: aantalNormTeams
# Setting Oud: type sport to Nieuw: typeSport
# Setting Oud: DatumBeginStatus to Nieuw: datumBeginStatus
# Setting Oud: DatumEindStatus to Nieuw: datumEindStatus
# Setting Oud: Status to Nieuw: status
# Setting Oud: StatusCode to Nieuw: statuscode
# Setting Oud: StatusVolgorde to Nieuw: statusVolgorde
# Setting Oud: Aangemaaktdoor to Nieuw: aangemaaktDoor
# Setting Oud: Aanmaakdatum to Nieuw: datumAanmaak
# Setting Oud: Activiteit to Nieuw: activiteit
# Setting Oud: ControleElement to Nieuw: controleElement
# Setting Oud: Controleniveau to Nieuw: controleniveau
# Setting Oud: Diepte to Nieuw: diepte
# Setting Oud: Fase to Nieuw: fase
# Setting Oud: Gemuteerddoor to Nieuw: gemuteerdDoor
# Setting Oud: Mutatiedatum to Nieuw: datumMutatie
# Setting Oud: Resultaat to Nieuw: resultaat
# Setting Oud: Risico to Nieuw: risico
# Setting Oud: Omschrijving to Nieuw: omschrijving
# Setting Oud: aangemaakt_door to Nieuw: aangemaaktDoor
# Setting Oud: aanmaakdatum to Nieuw: datumAanmaak
# Setting Oud: datumgepland to Nieuw: datumGepland
# Setting Oud: gemuteerd_door to Nieuw: gemuteerdDoor
# Setting Oud: inspectiedatum to Nieuw: datumInspectie
# Setting Oud: mutatiedatum to Nieuw: datumMutatie
# Setting Oud: Aangemaakt_door to Nieuw: aangemaaktDoor
# Setting Oud: AanmaakDatum to Nieuw: datumAanmaak
# Setting Oud: Aantal to Nieuw: aantal
# Setting Oud: Bedrag to Nieuw: bedrag
# Setting Oud: Bedragtotaal to Nieuw: bedragTotaal
# Setting Oud: Eenheid to Nieuw: eenheid
# Setting Oud: gefactureerd_op to Nieuw: gefactureerdOp
# Setting Oud: gemuteerd_door to Nieuw: gemuteerdDoor
# Setting Oud: mutatiedatum to Nieuw: datumMutatie
# Setting Oud: Naam to Nieuw: naam
# Setting Oud: Omschrijving to Nieuw: omschrijving
# Setting Oud: Opbasisvangrondslag to Nieuw: opBasisVanGrondslag
# Setting Oud: Tarief to Nieuw: tarief
# Setting Oud: Type to Nieuw: type
# Setting Oud: Vastgesteldbedrag to Nieuw: vastgesteldBedrag
# Setting Oud: Aangemaakt_door to Nieuw: aangemaaktDoor
# Setting Oud: AanmaakDatum to Nieuw: datumAanmaak
# Setting Oud: AantalOpgegeven to Nieuw: aantalOpgegeven
# Setting Oud: AantalVastgesteld to Nieuw: aantalVastgesteld
# Setting Oud: Automatisch to Nieuw: automatisch
# Setting Oud: Eenheid to Nieuw: eenheid
# Setting Oud: Gemuteerd_door to Nieuw: gemuteerdDoor
# Setting Oud: LegesGrondslag to Nieuw: legesGrondslag
# Setting Oud: MutatieDatum to Nieuw: datumMutatie
# Setting Oud: Omschrijving to Nieuw: omschrijving
# Setting Oud: CROW to Nieuw: crow
# Setting Oud: locatie omschrijving to Nieuw: locatieOmschrijving
# Setting Oud: melding omschrijving to Nieuw: meldingOmschrijving
# Setting Oud: melding tekst to Nieuw: meldingTekst
# Setting Oud: einddatum to Nieuw: datumEind
# Setting Oud: locatieomschrijving to Nieuw: locatieOmschrijving
# Setting Oud: startdatum to Nieuw: datumStart
# Setting Oud: Omschrijving to Nieuw: omschrijving
# Setting Oud: naam vaartuig to Nieuw: naamVaartuig
# Setting Oud: BAGID to Nieuw: bagID
# Setting Oud: intern nummer to Nieuw: internNummer
# Setting Oud: kadastrale aanduiding to Nieuw: kadastraleAanduiding
# Setting Oud: locatieomschrijving to Nieuw: locatieOmschrijving
# Setting Oud: Aangemaakt_door to Nieuw: aangemaaktDoor
# Setting Oud: Aanmaakdatum to Nieuw: datumAanmaak
# Setting Oud: Btw_bedrag to Nieuw: bedragBTW
# Setting Oud: Geaccordeerd to Nieuw: geaccordeerd
# Setting Oud: Geaccordeerd_door to Nieuw: geaccordeerdDoor
# Setting Oud: Geaccordeerd_op to Nieuw: geaccordeerdOp
# Setting Oud: Geexporteerd to Nieuw: geexporteerd
# Setting Oud: Gemuteerd_door to Nieuw: gemuteerdDoor
# ...
# Setting Oud: Naam cultuurcode onbebouwd to Nieuw: naamCultuurcodeOnbebouwd
# Setting Oud: Begindatum geldigheid deelojectcode to Nieuw: datumBeginGeldigheidDeelojectcode
# Setting Oud: Deelobjectcode to Nieuw: deelobjectcode
# Setting Oud: Einddatum geldigheid deelobjectcode to Nieuw: datumEindeGeldigheidDeelobjectcode
# Setting Oud: Naam deelobjectcode to Nieuw: naamDeelobjectcode
# Setting Oud: Begindatum geldigheid kadastrale gemeente to Nieuw: datumBeginGeldigheidKadastraleGemeente
# Setting Oud: Einddatum geldigheid kadastrale gemeente to Nieuw: datumEindeGeldigheidKadastraleGemeente
# Setting Oud: Kadastrale gemeentecode to Nieuw: kadastraleGemeentecode
# Setting Oud: Naam to Nieuw: naam
# Setting Oud: Einddatum land to Nieuw: datumEindeLand
# Setting Oud: Ingangsdatum land to Nieuw: datumIngangLand
# Setting Oud: Landcode to Nieuw: landcode
# Setting Oud: Landcode ISO to Nieuw: landcodeISO
# Setting Oud: Landnaam to Nieuw: landnaam
# Setting Oud: Einddatum provincie to Nieuw: datumEindeProvincie
# Setting Oud: Hoofdstad to Nieuw: hoofdstad
# Setting Oud: Ingangsdatum provincie to Nieuw: datumIngangProvincie
# Setting Oud: oppervlakte land to Nieuw: oppervlakteLand
# Setting Oud: Provinciecode to Nieuw: provinciecode
# Setting Oud: Provincienaam to Nieuw: provincienaam
# Setting Oud: Code to Nieuw: code
# Setting Oud: Datum aanvang geldigheid partij to Nieuw: datumAanvangGeldigheidPartij
# Setting Oud: Datum einde geldigheid partij to Nieuw: datumEindeGeldigheidPartij
# Setting Oud: Naam to Nieuw: naam
# Setting Oud: Soort to Nieuw: soort
# Setting Oud: VerstrekkingsbeperkingMogelijk? to Nieuw: verstrekkingsbeperkingMogelijk
# Setting Oud: Datum aanvang geldigheid verkrijging to Nieuw: datumAanvangGeldigheidVerkrijging
# Setting Oud: Datum einde geldigheid verkrijging to Nieuw: datumEindeGeldigheidVerkrijging
# Setting Oud: Omschrijving verkrijging to Nieuw: omschrijvingVerkrijging
# Setting Oud: Redennummer verkrijging to Nieuw: redennummerVerkrijging
# Setting Oud: Datum aanvang geldigheid verlies to Nieuw: datumAanvangGeldigheidVerlies
# Setting Oud: Datum einde geldigheid verlies to Nieuw: datumEindeGeldigheidVerlies
# Setting Oud: Omschrijving verlies to Nieuw: omschrijvingVerlies
# Setting Oud: Redennummer verlies to Nieuw: redennummerVerlies
# Setting Oud: Begindatum geldigheid reisdocumentsoort to Nieuw: datumBeginGeldigheidReisdocumentsoort
# Setting Oud: Einddatum geldigheid reisdocumentsoort to Nieuw: datumEindeGeldigheidReisdocumentsoort
# Setting Oud: Reisdocumentcode to Nieuw: reisdocumentcode
# Setting Oud: Reisdocumentomschrijving to Nieuw: reisdocumentomschrijving
# Setting Oud: Einddatum SBI Activiteit to Nieuw: datumEindeSBIActiviteit
# Setting Oud: Hoofdniveau to Nieuw: hoofdniveau
# Setting Oud: Hoofdniveau omschrijving to Nieuw: hoofdniveauOmschrijving
# Setting Oud: Ingangsdatum SBI Activiteit to Nieuw: datumIngangSBIActiviteit
# Setting Oud: Naam activiteit to Nieuw: naamActiviteit
# Setting Oud: SBI code to Nieuw: sbiCode
# Setting Oud: SBI Groep to Nieuw: sbiGroep
# Setting Oud: SBI Groep omschrijving to Nieuw: sbiGroepOmschrijving
# Setting Oud: Begindatum geldigheid soort grootte to Nieuw: datumBeginGeldigheidSoortGrootte
# Setting Oud: Code soort grootte to Nieuw: codeSoortGrootte
# Setting Oud: Einddatum geldigheid soort grootte to Nieuw: datumEindeGeldigheidSoortGrootte
# Setting Oud: Naam soort grootte to Nieuw: naamSoortGrootte
# Setting Oud: Begindatum geldigheid soort objectcode to Nieuw: datumBeginGeldigheidSoortObjectcode
# Setting Oud: Einddatum geldigheid soort objectcode to Nieuw: datumEindeGeldigheidSoortObjectcode
# Setting Oud: Naam soort objectcode to Nieuw: naamSoortObjectcode
# Setting Oud: Opmerking soort objectcode to Nieuw: opmerkingSoortObjectcode
# Setting Oud: Soort objectcode to Nieuw: soortobjectcode
# Setting Oud: Begindatum geldigheid valutasoort to Nieuw: datumBeginGeldigheidValutasoort
# Setting Oud: Einddatum geldigheid valutasoort to Nieuw: datumEindeGeldigheidValutasoort
# Setting Oud: Naam valuta to Nieuw: naamValuta
# Setting Oud: Valutacode to Nieuw: valutacode
# Setting Oud: Einddatum land to Nieuw: datumEindeLand
# Setting Oud: Einddatum.fictief to Nieuw: DatumeindeFictief
# Setting Oud: Ingangsdatum land to Nieuw: datumIngangLand
# Setting Oud: Landcode to Nieuw: landcode
# Setting Oud: Landcode ISO 2-letterig to Nieuw: landcodeISOTweeletterig
# Setting Oud: Landcode ISO 3-letterig to Nieuw: landcodeISODrieletterig
# Setting Oud: Landnaam to Nieuw: landnaam
# Setting Oud: Begindatum geldigheid nationaliteit to Nieuw: datumBeginGeldigheidNationaliteit
# Setting Oud: Einddatum geldigheid nationaliteit to Nieuw: datumEindeGeldigheidNationaliteit
# Setting Oud: Nationaliteitcode to Nieuw: codeNationaliteit
# Setting Oud: Nationaliteitomschrijving to Nieuw: nationaliteitOmschrijving
# Setting Oud: Begindatum geldigheid to Nieuw: datumBeginGeldigheid
# Setting Oud: Einddatum geldigheid to Nieuw: datumEindeGeldigheid
# Setting Oud: Naam to Nieuw: naam
# Setting Oud: Valutacode to Nieuw: valutacode
# Setting Oud: achtergrond melding to Nieuw: achtergrondMelding
# Setting Oud: datum afgedaan to Nieuw: datumAfgedaan
# Setting Oud: datum begrafenis to Nieuw: datumBegrafenis
# Setting Oud: datum gemeld to Nieuw: datumGemeld
# Setting Oud: datum ruiming graf to Nieuw: datumRuimingGraf
# Setting Oud: gemeentelijke kosten to Nieuw: gemeentelijkeKosten
# Setting Oud: uren gemeente to Nieuw: urenGemeente
# Setting Oud: verhaald bedrag to Nieuw: verhaaldBedrag
# Setting Oud: Afsluitreden to Nieuw: redenAfsluiting
# Setting Oud: ClientReactie to Nieuw: clientReactie
# Setting Oud: Datumbeschikking to Nieuw: datumBeschikking
# Setting Oud: Datumeersteafspraak to Nieuw: datumEersteAfspraak
# Setting Oud: Datumplanvastgesteld to Nieuw: datumPlanVastgesteld
# Setting Oud: Datumstartaanvraag to Nieuw: datumStartAanvraag
# Setting Oud: Deskundigheid to Nieuw: deskundigheid
# Setting Oud: Doorloopmethodiek to Nieuw: doorloopmethodiek
# Setting Oud: Einddatum to Nieuw: datumEind
# Setting Oud: MaximaleDoorlooptijd to Nieuw: maximaleDoorlooptijd
# Setting Oud: Aanmelder to Nieuw: aanmelder
# Setting Oud: AanmeldingDoor to Nieuw: aanmeldingDoor
# Setting Oud: AanmeldingDoorLandelijk to Nieuw: aanmeldingDoorLandelijk
# Setting Oud: Aanmeldwijze to Nieuw: aanmeldwijze
# Setting Oud: Afsluitreden to Nieuw: redenAfsluiting
# Setting Oud: Deskundigheid to Nieuw: deskundigheid
# Setting Oud: IsClientOpdeHoogte to Nieuw: isClientOpdeHoogte
# Setting Oud: Onderzoekswijze to Nieuw: onderzoekswijze
# Setting Oud: Vervolg to Nieuw: vervolg
# Setting Oud: Verwezen to Nieuw: verwezen
# Setting Oud: afgiftedatum to Nieuw: datumAfgifte
# Setting Oud: einddatum to Nieuw: datumEind
# Setting Oud: ingangsdatum to Nieuw: datumStart
# Setting Oud: OorspronkelijkeEinddatum to Nieuw: datumEindeOorspronkelijk
# Setting Oud: Redeneinde to Nieuw: redenEinde
# Setting Oud: Status to Nieuw: status
# Setting Oud: uitgenut bedrag to Nieuw: uitgenutBedrag
# Setting Oud: gezagsdragerbekend to Nieuw: gezagsdragerGekend
# Setting Oud: juridische status to Nieuw: juridischeStatus
# Setting Oud: wettelijke vertegenwoordiging to Nieuw: wettelijkeVertegenwoordiging
# Setting Oud: declaratie bedrag to Nieuw: declaratieBedrag
# Setting Oud: Declaratie datum to Nieuw: datumDeclaratie
# Setting Oud: declaratie status to Nieuw: declaratieStatus
# Setting Oud: Bedrag to Nieuw: bedrag
# Setting Oud: Begin Datum to Nieuw: datumStart
# Setting Oud: Eind Datum to Nieuw: datumEind
# Setting Oud: einddatum to Nieuw: datumEind
# Setting Oud: ingangsdatum to Nieuw: datumStart
# Setting Oud: AGB-Code to Nieuw: agbCode
# Setting Oud: Leverancierscode to Nieuw: leverancierscode
# Setting Oud: Naam to Nieuw: naam
# Setting Oud: Soort leverancier to Nieuw: soortLeverancier
# Setting Oud: Soort leverancier code to Nieuw: soortLeverancierCode
# Setting Oud: startdatum to Nieuw: datumStart
# Setting Oud: stopdatum to Nieuw: datumStop
# Setting Oud: leveringsvormcode to Nieuw: leveringsvormCode
# Setting Oud: startdatum to Nieuw: datumStart
# Setting Oud: stopdatum to Nieuw: datumStop
# Setting Oud: einddatum to Nieuw: datumEind
# Setting Oud: toekenningsdatum to Nieuw: datumToekenning
# Setting Oud: Eenheid to Nieuw: eenheid
# Setting Oud: einddatum to Nieuw: datumEind
# Setting Oud: startdatum to Nieuw: datumStart
# Setting Oud: aanschafdatum to Nieuw: datumAanschaf
# Setting Oud: datum eind toewijzing to Nieuw: datumEindeToewijzing
# Setting Oud: datum start toewijzing to Nieuw: datumStartToewijzing
# Setting Oud: toewijzingsdatum to Nieuw: datumToewijzing
# Setting Oud: beschikkingsingangsdatum to Nieuw: datumIngangBeschikking
# Setting Oud: ontvangstdatum to Nieuw: datumOntvangst
# Setting Oud: soort verwijzer to Nieuw: soortVerwijzer
# Setting Oud: toewijzingseinddatum to Nieuw: datumEindeToewijzing
# Setting Oud: toewijzingsingangsdatum to Nieuw: datumIngangToewijzing
# Setting Oud: einddatumgeldigheid to Nieuw: datumEindeGeldigheid
# Setting Oud: startdatumgeldigheid to Nieuw: datumStartGeldigheid
# Setting Oud: datumvastgesteld to Nieuw: datumVastgesteld
# Setting Oud: einddatum to Nieuw: datumEind
# Setting Oud: startdatum to Nieuw: datumStart
# Setting Oud: toekennningsdatum to Nieuw: datumToekenning
# Setting Oud: einddatum to Nieuw: datumEind
# Setting Oud: startdatum to Nieuw: datumStart
# Setting Oud: toekenningsdatum to Nieuw: datumToekenning
# Setting Oud: einddatum to Nieuw: datumEind
# Setting Oud: startdatum to Nieuw: datumStart
# Setting Oud: einddatum to Nieuw: datumEind
# Setting Oud: startdatum to Nieuw: datumStart
# Setting Oud: vaststellingsdatum to Nieuw: datumVaststelling
# Setting Oud: Bedrag to Nieuw: bedrag
# Setting Oud: Datum_begin_betrekkingop to Nieuw: datumBeginBetrekkingOp
# Setting Oud: Datum_eind_betrekkingop to Nieuw: datumEindBetrekkingOp
# Setting Oud: DebetCredit to Nieuw: debetCredit
# Setting Oud: Groep to Nieuw: groep
# Setting Oud: GroepCode to Nieuw: groepCode
# Setting Oud: GrootboekCode to Nieuw: grootboekCode
# Setting Oud: GrootboekOmschrijving to Nieuw: grootboekOmschrijving
# Setting Oud: Kostenplaats to Nieuw: kostenplaats
# Setting Oud: Omschrijving to Nieuw: omschrijving
# Setting Oud: RekeningNummer to Nieuw: rekeningnummer
# Setting Oud: Toelichting to Nieuw: toelichting
# Setting Oud: Component to Nieuw: component
# Setting Oud: ComponentCode to Nieuw: componentCode
# Setting Oud: Kolom to Nieuw: kolom
# Setting Oud: KolomCode to Nieuw: kolomCode
# Setting Oud: Regeling to Nieuw: regeling
# Setting Oud: RegelingCode to Nieuw: regelingCode
# Setting Oud: datumgeconstateerd to Nieuw: datumGeconstateerd
# Setting Oud: einddatumFraude to Nieuw: datumEindeFraude
# Setting Oud: fraudebedrag to Nieuw: bedragFraude
# Setting Oud: startdatumFraude to Nieuw: datumStartFraude
# Setting Oud: einddatum to Nieuw: datumEind
# Setting Oud: gemeente oorsprong to Nieuw: gemeenteOorsprong
# Setting Oud: startdatum to Nieuw: datumStart
# Setting Oud: toestemming gemeentelijk briefadres to Nieuw: toestemmingGemeentelijkBriefadres
# Setting Oud: toestemming nachtopvang to Nieuw: toestemmingNachtopvang
# Setting Oud: einddatum to Nieuw: datumEind
# Setting Oud: ingangsdatum to Nieuw: datumStart
# Setting Oud: toekenningsdatum to Nieuw: datumToekenning
# Setting Oud: regelingscode to Nieuw: regelingCode
# Setting Oud: ClientbegeleiderID to Nieuw: clientbegeleiderID
# Setting Oud: einddatum begeleiding to Nieuw: datumEindeBegeleiding
# Setting Oud: Indicatie doelgroepregister to Nieuw: indicatieDoelgroepregister
# Setting Oud: startdatum begeleiding to Nieuw: datumStartBegeleiding
# Setting Oud: einddatum to Nieuw: datumEind
# Setting Oud: startdatum to Nieuw: datumStart
# Setting Oud: toekenningsdatum to Nieuw: datumToekenning
# Setting Oud: einddatum to Nieuw: datumEind
# Setting Oud: startdatum to Nieuw: datumStart
# Setting Oud: einddatum to Nieuw: datumEind
# Setting Oud: startdatum to Nieuw: datumStart
# Setting Oud: toekenningsdatum to Nieuw: datumToekenning
# Setting Oud: Contract to Nieuw: contract
# Setting Oud: Crediteur to Nieuw: crediteur
# Setting Oud: Datum Begin to Nieuw: datumBegin
# Setting Oud: Datum Status to Nieuw: datumStatus
# Setting Oud: Datum_Einde to Nieuw: datumEind
# Setting Oud: Kinderopvang to Nieuw: kinderopvang
# Setting Oud: Status to Nieuw: status
# Setting Oud: Succesvol to Nieuw: succesvol
# Setting Oud: Aanleveren SRG to Nieuw: aanleverenSRG
# Setting Oud: Omschrijving to Nieuw: omschrijving
# Setting Oud: Type Traject SRG to Nieuw: typeTrajectSRG
# Setting Oud: DatumRun to Nieuw: datumRun
# Setting Oud: Frequentie to Nieuw: frequentie
# Setting Oud: PeriodeRun to Nieuw: periodeRun
# Setting Oud: SoortRun to Nieuw: soortRun
# Setting Oud: betaaldatum to Nieuw: datumBetaling
# Setting Oud: bezwaarafgehandeld to Nieuw: bezwaarAfgehandeld
# Setting Oud: bezwaardatum to Nieuw: datumBezwaar
# Setting Oud: bezwaaringetrokken to Nieuw: bezwaarIngetrokken
# Setting Oud: bezwaartoegewezen to Nieuw: bezwaarToegewezen
# Setting Oud: bonnr to Nieuw: bonnummer
# Setting Oud: dienstcd to Nieuw: dienstCD
# Setting Oud: geseponeerddatum to Nieuw: datumGeseponeerd
# Setting Oud: indiendatum to Nieuw: datumIndien
# Setting Oud: redenseponeren to Nieuw: redenSeponeren
# Setting Oud: vorderingnr to Nieuw: vorderingnummer
# Setting Oud: betaaldatum to Nieuw: datumBetaling
# Setting Oud: bezwaarafgehandeld to Nieuw: bezwaarAfgehandeld
# Setting Oud: bezwaardatum to Nieuw: datumBezwaar
# Setting Oud: bezwaaringetrokken to Nieuw: bezwaarIngetrokken
# Setting Oud: bezwaartoegewezen to Nieuw: bezwaarToegewezen
# Setting Oud: bonnr to Nieuw: bonnummer
# Setting Oud: dienstcd to Nieuw: dienstCD
# Setting Oud: geseponeerddatum to Nieuw: datumGeseponeerd
# Setting Oud: indiendatum to Nieuw: datumIndien
# Setting Oud: redenseponeren to Nieuw: redenSeponeren
# Setting Oud: vorderingnr to Nieuw: vorderingnummer
# Setting Oud: Aankoopbedrag to Nieuw: bedragAankoop
# Setting Oud: BTW-bedrag to Nieuw: bedragBTW
# Setting Oud: einddatumtijd to Nieuw: datumtijdEinde
# Setting Oud: Productnaam to Nieuw: productnaam
# Setting Oud: Productomschrijving to Nieuw: productomschrijving
# Setting Oud: startdatumtijd to Nieuw: datumtijdStart
# Setting Oud: code gebruiker to Nieuw: codeGebruiker
# Setting Oud: code scanvoertuig to Nieuw: codeScanvoertuig
# Setting Oud: geldigtot to Nieuw: datumEindeGeldigheid
# Setting Oud: geldigvanaf to Nieuw: datumStart
# Setting Oud: minuten afgeschreven to Nieuw: minutenAfgeschreven
# Setting Oud: minuten geldig to Nieuw: minutenGeldig
# Setting Oud: minuten resterend to Nieuw: minutenResterend
# Setting Oud: reserveringsdatum to Nieuw: datumReservering
# Setting Oud: vlakid to Nieuw: vlakID
# Setting Oud: aantal parkeervlakken to Nieuw: aantalParkeervlakken
# Setting Oud: alleen dagtarief to Nieuw: alleenDagtarief
# Setting Oud: gemometrie to Nieuw: geometrie
# Setting Oud: IPM-code to Nieuw: ipmCode
# Setting Oud: IPM-naam to Nieuw: ipmNaam
# Setting Oud: Parkeergarage to Nieuw: parkeergarage
# Setting Oud: soort_code to Nieuw: soortCode
# Setting Oud: type_code to Nieuw: typeCode
# Setting Oud: type_naam to Nieuw: typeNaam
# Setting Oud: zone_code to Nieuw: zoneCode
# Setting Oud: Type to Nieuw: type
# Setting Oud: aanmelddatum to Nieuw: datumAanmelding
# Setting Oud: aantal gehinderden to Nieuw: aantalGehinderden
# Setting Oud: delen toegestaan to Nieuw: delenToegestaan
# Setting Oud: einddatum to Nieuw: datumEind
# Setting Oud: geschikt voor publicatie to Nieuw: geschiktVoorPublicatie
# Setting Oud: startdatum to Nieuw: datumStart
# Setting Oud: wijzigingsdatum to Nieuw: datumWijziging
# Setting Oud: maximum temperatuur to Nieuw: maximumtemperatuur
# Setting Oud: minimum temperatuur to Nieuw: minimumtemperatuur
# Setting Oud: tijd maximum temperatuur to Nieuw: tijdMaximumtemperatuur
# Setting Oud: tijd minimum temperatuur to Nieuw: tijdMinimumtemperatuur
# Setting Oud: gepland einde to Nieuw: geplandEinde
# Setting Oud: gepland start to Nieuw: geplandStart
# Setting Oud: werkelijk einde to Nieuw: werkelijkEinde
# Setting Oud: werkelijk start to Nieuw: werkelijkeStart
# Setting Oud: detectieverkeer to Nieuw: detectieVerkeer
# Setting Oud: verkeerwilgroen to Nieuw: verkeerWilGroen
# Setting Oud: besluitdatum to Nieuw: datumBesluit
# Setting Oud: einddatum to Nieuw: datumEind
# Setting Oud: ingangsdatum to Nieuw: datumStart
# Setting Oud: tijdstip tot to Nieuw: tijdTot
# Setting Oud: tijdstip vanaf to Nieuw: tijdVanaf
